# %%
from active_critic.analyze_stats.analyze_stats import make_plot

AC_path = '/home/hendrik/Documents/master_project/LokalData/server/AC/0331_stats/'
include_AC = ['statsoptimized', 'windowopen reset windowopen opt steps: 3 trainin eps: 1000 opt mode: actor+plan demonstrations: 1, im_ph:False, training_episodes: 10, min critic: 1e-05, wd: 0.01, val_every: 1000']
exclude_AC = []

PPO_path = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-30/'
include_PPO = ['learner', 'PPO_windowopen_lr_0.0005_demonstrations_1_n_samples_5000']
exclude_PPO = []

TQC_path = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-30/'
include_TQC = ['learner', "TQC_windowopen_lr_0.0001_demonstrations_1_n_samples_5000"]
exclude_TQC = []

save_path = '/home/hendrik/Documents/Master Thesis/TUM_Thesis_Template_CSE/images/dense_1/'


make_plot(
    paths=[AC_path, PPO_path, TQC_path], 
    includes=[include_AC, include_PPO, include_TQC], 
    excludes=[exclude_AC, exclude_PPO, exclude_TQC],
    names=['COAVC (ours)', 'PPO', 'TQC', 'RPPO'],
    plot_name='Window Open',
    save_path = save_path,
    plot_closest=False,
    mean=False,
    loc='lower right',
    total_plot_points=60,
    font_size=28,
    legend_font_size = 18
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/0331_stats/: 3
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-30/: 3
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-30/: 3

# %%
from active_critic.analyze_stats.analyze_stats import make_plot

AC_path_1 = '/home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-05-12/'
include_AC_1 = ['statsoptimized', 'windowopen']
exlude_AC1 = []

PPO_path = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-30/'
include_PPO = ['learner', 'PPO_windowopen_lr_0.0005_demonstrations_1_n_samples_5000']
exclude_PPO = []

TQC_path = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-30/'
include_TQC = ['learner', "TQC_windowopen_lr_0.0001_demonstrations_1_n_samples_5000"]
exclude_TQC = []

save_path = '/home/hendrik/Documents/Master Thesis/TUM_Thesis_Template_CSE/images/dense_1/'


make_plot(
    paths=[AC_path_1, PPO_path, TQC_path], 
    includes=[include_AC_1, include_PPO, include_TQC], 
    excludes=[exlude_AC1, exclude_PPO, exclude_TQC],
    names=['COAVC (ours)', 'PPO', 'TQC', 'RPPO'],
    plot_name='Window Open',
    save_path = save_path,
    plot_closest=False,
    mean=False,
    loc='lower right',
    total_plot_points=60,
    font_size=28,
    legend_font_size = 18
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-05-12/: 2
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-30/: 3
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-30/: 3

# %%
from active_critic.analyze_stats.analyze_stats import make_plot


AC_path = '/home/hendrik/Documents/master_project/LokalData/server/AC/0331_stats/'
include_AC = ['statsoptimized', 'windowopen reset windowopen opt steps: 3 trainin eps: 1000 opt mode: actor+plan demonstrations: 1, im_ph:False, training_episodes: 10, min critic: 1e-05, wd: 0.01, val_every: 1000']
exclude_AC = []


AC_path_so = '/home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-04-01/'
include_AC_so = ['stats', 'windowopen sp_obs history eps: 1000 opt mode: actor+plan demonstrations: 1, im_ph:False, training_episodes: 10, min critic: 5e-05, wd: 0.01, val_every: 6000']
exclude_AC_so = ['optimize']

save_path = '/home/hendrik/Documents/Master Thesis/TUM_Thesis_Template_CSE/images/dense_vs_sparse_1/'


make_plot(
    paths=[AC_path, AC_path_so], 
    includes=[include_AC, include_AC_so], 
    excludes=[exclude_AC, exclude_AC_so],
    names=['AVC Dense Observations', 'AVC Single Observations'],
    plot_name='Window Open',
    save_path = save_path,
    plot_closest=False,
    mean=False,
    find_closest=False,
    total_plot_points=60,
    font_size=28,
    legend_font_size=18,
    plot_legend=False
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/0331_stats/: 3
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-04-01/: 2

# %%
from active_critic.analyze_stats.analyze_stats import make_plot
AC_path_1 = '/home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-05-12/'
include_AC_1 = ['statsoptimized', 'windowopen']
exlude_AC1 = []

make_plot(
    paths=[AC_path_1,], 
    includes=[include_AC_1,], 
    excludes=[exlude_AC1,],
    names=['AVC', 'AVC non', 'TQC + BC'],
    plot_name='Push Environment',
    save_path = None,
    plot_closest=False,
    find_closest=True,
    total_plot_points=1000
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-05-12/: 2
