# %%
from active_critic.analyze_stats.analyze_stats import make_plot

AC_path = '/home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-25/'

include_AC = ['pickplace 1e-4 opr lr trainin eps: 400 opt mode: actor+plan demonstrations: 15, im_ph:False, training_episodes: 10, min critic: 5e-05, wd: 0.01, val_every: 6000', 'statsoptimized']
exclude_AC = []

PPO_path = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-26/'
include_PPO = ['PPO_GAIL_pickplace_lr_1e-05_demonstrations_15', 'learner']
exclude_PPO = []

RPPO_path = '/data/bing/hendrik/Baselines_Stats_GAIL_2023-03-28/'
include_RPPO = ['RPPO_pickplace_lr_1e-06_demonstrations_15', 'learner']
exclude_RPPO = []

TQC_path = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-27/'
include_TQC = ['TQC_GAIL_pickplace_lr_1e-07_demonstrations_15', 'learner']
exclude_TQC = []

save_path = '/home/hendrik/Documents/master_project/LokalData/server/Stats for MA/15_400'


make_plot(
    paths=[AC_path, PPO_path, TQC_path, RPPO_path], 
    includes=[include_AC, include_PPO, include_TQC, include_RPPO], 
    excludes=[exclude_AC, exclude_PPO, exclude_TQC, exclude_RPPO],
    names=['AC', 'PPO + BC + GAIL', 'TQC + BC + GAIL', 'RPPO + BC'],
    plot_name='Pick and Place',
    save_path = save_path,
    plot_closest=False,
    mean=False
    )

save_path = '/home/hendrik/Documents/Master Thesis/TUM_Thesis_Template_CSE/images/15_400/'
make_plot(
    paths=[AC_path, PPO_path, TQC_path, RPPO_path], 
    includes=[include_AC, include_PPO, include_TQC, include_RPPO], 
    excludes=[exclude_AC, exclude_PPO, exclude_TQC, exclude_RPPO],
    names=['AC', 'PPO + BC + GAIL', 'TQC + BC + GAIL', 'RPPO + BC'],
    plot_name='Pick and Place',
    save_path = save_path,
    plot_closest=False,
    mean=False
    )

save_path = '/home/hendrik/Documents/Master Thesis/TUM_Thesis_Template_CSE/images/FineTuning/'
make_plot(
    paths=[AC_path, PPO_path, TQC_path, RPPO_path], 
    includes=[include_AC, include_PPO, include_TQC, include_RPPO], 
    excludes=[exclude_AC, exclude_PPO, exclude_TQC, exclude_RPPO],
    names=['AC', 'PPO + BC + GAIL', 'TQC + BC + GAIL', 'RPPO + BC'],
    plot_name='Pick and Place',
    save_path = save_path,
    plot_closest=False,
    mean=False
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-25/: 4
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-26/: 3
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-27/: 3
# for path: /data/bing/hendrik/Baselines_Stats_GAIL_2023-03-28/: 3
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-25/: 4
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-26/: 3
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-27/: 3
# for path: /data/bing/hendrik/Baselines_Stats_GAIL_2023-03-28/: 3
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-25/: 4
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-26/: 3
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-27/: 3
# for path: /data/bing/hendrik/Baselines_Stats_GAIL_2023-03-28/: 3

# %%
from active_critic.analyze_stats.analyze_stats import make_plot

AC_path = '/home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-25/'

include_AC = ['pickplace 1e-4 opr lr trainin eps: 400 opt mode: actor+plan demonstrations: 15, im_ph:False, training_episodes: 10, min critic: 5e-05, wd: 0.01, val_every: 6000', 'statsoptimized']
exclude_AC = []

include_AC_non = ['pickplace 1e-4 opr lr trainin eps: 400 opt mode: actor+plan demonstrations: 15, im_ph:False, training_episodes: 10, min critic: 5e-05, wd: 0.01, val_every: 6000', 'stats']
exclude_AC_non = ['optimized']

save_path = '/home/hendrik/Documents/master_project/LokalData/server/Stats for MA/15_400'


make_plot(
    paths=[AC_path, AC_path], 
    includes=[include_AC, include_AC_non], 
    excludes=[exclude_AC, exclude_AC_non],
    names=['AC', 'PPO + BC + GAIL', 'TQC + BC + GAIL', 'RPPO + BC'],
    plot_name='Pick and Place',
    save_path = None,
    plot_closest=False,
    mean=False
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-25/: 4
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-25/: 4
