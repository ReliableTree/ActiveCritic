# %%
from active_critic.analyze_stats.analyze_stats import make_plot

PPO_Path ='/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-26/'
include_PPO = ['PPO_GAIL_windowopen_lr_1e-05_demonstrations_15', 'learner']
exclude_PPO = []

RPPO_path = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-27/'
include_RPPO = ['RPPO_windowopen_lr_1e-05_demonstrations_15', 'learner']
exluce_RPPO = []

TQC_path = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-27/'

include_TQC = ['TQC_GAIL_windowopen_lr_1e-07_demonstrations_15', 'learner']
exclude_TQC = []

RPPO_path = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-04-06'
include_RPPO = ['learner', 'learner', 'RPPO_windowopen_lr_1e-06_demonstrations_15']
exclude_RPPO = [
    
]
save_path = '/home/hendrik/Documents/master_project/LokalData/server/Stats for MA/15_400'


make_plot(
    paths=[PPO_Path, TQC_path, RPPO_path], 
    includes=[include_PPO, include_TQC, include_RPPO], 
    excludes=[exclude_PPO, exclude_TQC, exluce_RPPO],
    names=['AC', 'PPO + BC + GAIL', 'TQC + BC + GAIL', 'RPPO + BC'],
    plot_name='Window Open',
    save_path = save_path,
    plot_closest=False
    )

save_path = '/home/hendrik/Documents/Master Thesis/TUM_Thesis_Template_CSE/images/15_400/'
make_plot(
    paths=[PPO_Path, TQC_path, RPPO_path], 
    includes=[include_PPO, include_TQC, include_RPPO], 
    excludes=[exclude_PPO, exclude_TQC, exluce_RPPO],
    names=['AC', 'PPO + BC + GAIL', 'TQC + BC + GAIL', 'RPPO + BC'],
    plot_name='Window Open',
    save_path = save_path,
    plot_closest=False
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-26/: 3
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-27/: 3
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-27/: 3
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-26/: 3
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-27/: 3
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-27/: 3
