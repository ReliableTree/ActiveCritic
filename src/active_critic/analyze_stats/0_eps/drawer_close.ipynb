# %%
from active_critic.analyze_stats.analyze_stats import make_plot

AC_path = '/home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-28/'
include_AC = ['drawerclose sm manual_seed(0) no train inf eps: 1000 opt mode: actor+plan demonstrations: 0, im_ph:False, training_episodes: 10, min critic: 5e-05, wd: 0.01, val_every: 6000', 'stats']
exclude_AC = ['optimized']

PPO_path = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-25/'
include_PPO = ['PPO_drawerclose_lr_1e-05_demonstrations_0_n_samples_1000', 'learner']
exclude_PPO = []

TQC_path = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-25/'
include_TQC = ['TQC_drawerclose_lr_1e-06_demonstrations_0_n_samples_1000', 'learner']
exclude_TQC = []

save_path = '/home/hendrik/Documents/Master Thesis/TUM_Thesis_Template_CSE/images/0/'


make_plot(
    paths=[AC_path, PPO_path, TQC_path], 
    includes=[include_AC, include_PPO, include_TQC], 
    excludes=[exclude_AC, exclude_PPO,exclude_TQC],
    names=['AC', 'PPO + BC + GAIL', 'TQC + BC + GAIL', 'RPPO + BC'],
    plot_name='Drawer Close',
    save_path = save_path,
    plot_closest=True,
    mean=False
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-28/: 4
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-25/: 3
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-25/: 3

# %%
from active_critic.analyze_stats.analyze_stats import make_plot


AC_path = '/home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-28/'
include_AC = ['drawerclose sm manual_seed(0) no train inf eps: 1000 opt mode: actor+plan demonstrations: 0, im_ph:False, training_episodes: 10, min critic: 5e-05, wd: 0.01, val_every: 6000', 'statsoptimized']
exclude = []

make_plot(
    paths=[AC_path], 
    includes=[include_AC], 
    excludes=[exclude],
    names=['AC optimized', 'AC non optimized'],
    plot_name='Push Environment',
    save_path = None,
    plot_closest=False
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-28/: 4

# %%
AC_path = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-28/'
include_AC = ['TQC_drawerclose_lr_1e-06_demonstrations_0_n_samples_1000', 'learner']
exclude = []

make_plot(
    paths=[AC_path], 
    includes=[include_AC], 
    excludes=[exclude],
    names=['AC optimized', 'AC non optimized'],
    plot_name='Push Environment',
    save_path = None,
    plot_closest=False
    )
