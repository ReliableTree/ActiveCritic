# %%
from active_critic.analyze_stats.analyze_stats import make_plot

AC_path = '/home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-28/'
include_AC = ['windowopen sm manual_seed(1) no train inf eps: 500 opt mode: actor+plan demonstrations: 1, im_ph:False, training_episodes: 10, min critic: 5e-05, wd: 0.01, val_every: 6000', 'statsoptimized']
exclude = []

path_AC_IM = '/data/bing/hendrik/AC_var_2023-03-27/'
include_AC_IM = ['windowopen sm manual_seed(1) no train inf eps: 500 opt mode: actor+plan demonstrations: 1, im_ph:True, training_episodes: 10, min critic: 5e-05, wd: 0.01, val_every: 6000', 'statsoptimized']
exclude_AC_IM = []
save_path = '/home/hendrik/Documents/Master Thesis/TUM_Thesis_Template_CSE/images/1_2000_imi/'

make_plot(
    paths=[AC_path, path_AC_IM], 
    includes=[include_AC, include_AC_IM], 
    excludes=[exclude, exclude_AC_IM],
    names=['AVC with Reinforcement', 'AVC Imitation Only'],
    plot_name='Window Open',
    save_path = save_path,
    plot_closest=False,
    mean=False,
    total_plot_points=60,
    font_size=19,
    legend_font_size=14
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-28/: 4
# for path: /data/bing/hendrik/AC_var_2023-03-27/: 2

# %%
from active_critic.analyze_stats.analyze_stats import make_plot

AC_path = '/home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-28/'
include_AC = ['windowopen sm manual_seed(1) no train inf eps: 500 opt mode: actor+plan demonstrations: 1, im_ph:False, training_episodes: 10, min critic: 5e-05, wd: 0.01, val_every: 6000', 'statsoptimized']
exclude_AC = []

PPO_path = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-28/'
include_PPO = ['PPO_windowopen_lr_5e-06_demonstrations_1_n_samples_500', 'learner']
exclude_PPO = []

TQC_path = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-28/'
include_TQC = ['TQC_windowopen_lr_5e-07_demonstrations_1_n_samples_500', 'learner']
exclude_TQC = []

RPPO_path = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-28/'
include_RPPO = ['RPPO_windowopen_lr_5e-07_demonstrations_1', 'learner']
exclude_RPPO = []

save_path = '/home/hendrik/Documents/Master Thesis/TUM_Thesis_Template_CSE/images/1_2000/'

make_plot(
    paths=[AC_path, PPO_path, TQC_path, RPPO_path], 
    includes=[include_AC, include_PPO, include_TQC, include_RPPO], 
    excludes=[exclude_AC, exclude_PPO, exclude_TQC, exclude_RPPO],
    names=['AVC', 'PPO + BC', 'TQC + BC', 'RPPO + BC'],
    plot_name='Window Open',
    save_path = save_path,
    plot_closest=False,
    mean=False,
    total_plot_points=60,
    loc='lower center',
    font_size=28,
    legend_font_size=14
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-28/: 4
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-28/: 2
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-28/: 2
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-28/: 2

# %%
AC_path = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-28/'
include_AC = ['RPPO_windowopen_lr_5e-07_demonstrations_1', 'learner']
exclude = []

make_plot(
    paths=[AC_path], 
    includes=[include_AC], 
    excludes=[exclude],
    names=['AVC optimized', 'AVC non optimized'],
    plot_name='Push Environment',
    save_path = None,
    plot_closest=False
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-28/: 2
