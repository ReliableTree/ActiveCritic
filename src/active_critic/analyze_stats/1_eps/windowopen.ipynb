# %%
from active_critic.analyze_stats.analyze_stats import make_plot

path_AC = '/data/bing/hendrik/AC_var_2023-03-24/'
include_AC = ['windowopen 1e-4 opr lr trainin eps: 1000 opt mode: actor+plan demonstrations: 1, im_ph:False, training_episodes: 10, min critic: 5e-05, wd: 0, val_every: 6000', 'statsoptimized']
exclude_AC = []

make_plot(
    paths=[path_AC], 
    includes=[include_AC], 
    excludes=[exclude_AC],
    names=['AC', 'PPO + BC + GAIL', 'TQC + BC + GAIL', 'RPPO + BC'],
    plot_name='Reach',
    save_path = None,
    plot_closest=True,
    mean=False
    )
# Out:
# for path: /data/bing/hendrik/AC_var_2023-03-24/: 1
