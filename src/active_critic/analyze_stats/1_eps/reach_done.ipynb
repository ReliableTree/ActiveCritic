# %%
from active_critic.analyze_stats.analyze_stats import make_plot

# %%
PPO_path = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-26/'
include_PPO = ['PPO_reach_lr_1e-05_demonstrations_1_n_samples_2000', 'learner']
exclude_PPO = ['15']

TQC_path = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-26/'
include_TQC = ['TQC_reach_lr_1e-06_demonstrations_1_n_samples_2000', 'learner']
exclude_TQC = ['15']

RPPO_path = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-27/'
include_RPPO = ['RPPO_reach_lr_1e-05_demonstrations_1', 'learner']
exclude_RPPO = ['15']

AC_path = '/home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-27'
include_AC = ['reach sm manual_seed(2) no train inf eps: 2000 opt mode: actor+plan demonstrations: 1, im_ph:False, training_episodes: 10, min critic: 5e-05, wd: 0.01, val_every: 6000 ', 'statsoptimized']
exclude_AC = []

save_path = '/home/hendrik/Documents/master_project/LokalData/server/Stats for MA/1_2000'

make_plot(
    paths=[AC_path, PPO_path, TQC_path,  RPPO_path], 
    includes=[include_AC, include_PPO, include_TQC, include_RPPO], 
    excludes=[exclude_AC, exclude_PPO, exclude_TQC, exclude_RPPO],
    names=['AC', 'PPO + BC + GAIL', 'TQC + BC + GAIL', 'RPPO + BC'],
    plot_name='Reach',
    save_path = save_path,
    plot_closest=True,
    mean=False
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-27: 2
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-26/: 2
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-26/: 2
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-27/: 2

# %%
AC_path = '/home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-27'
include_AC = ['reach sm manual_seed(2) no train inf eps: 2000 opt mode: actor+plan demonstrations: 1, im_ph:False, training_episodes: 10, min critic: 5e-05, wd: 0.01, val_every: 6000 ', 'statsoptimized']
exclude_AC = []

AC_path_non = '/home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-27'
include_AC_non = ['reach sm manual_seed(2) no train inf eps: 2000 opt mode: actor+plan demonstrations: 1, im_ph:False, training_episodes: 10, min critic: 5e-05, wd: 0.01, val_every: 6000 ', 'stats']
exclude_AC_non = ['optimized']

save_path = '/home/hendrik/Documents/master_project/LokalData/server/Stats for MA/1_2000'

make_plot(
    paths=[AC_path, AC_path_non], 
    includes=[include_AC, include_AC_non], 
    excludes=[exclude_AC, exclude_AC_non],
    names=['AC Optimized', 'AC Non Optimized'],
    plot_name='Reach Optimized',
    save_path = None,
    plot_closest=True,
    mean=False
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-27: 2
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-27: 2

# %%
from active_critic.analyze_stats.analyze_stats import make_plot

AC_path_actions = '/home/hendrik/Documents/master_project/LokalData/server/Stats for MA/reach_actions_vs_actor/'

include_AC_act = ['reach', 'statsoptimized']
exclude_AC_act = []

AC_path = '/home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-27'
include_AC = ['reach sm manual_seed(2) no train inf eps: 2000 opt mode: actor+plan demonstrations: 1, im_ph:False, training_episodes: 10, min critic: 5e-05, wd: 0.01, val_every: 6000 ', 'statsoptimized']
exclude_AC = []

save_path = '/home/hendrik/Documents/master_project/LokalData/server/Stats for MA/1_2000/'


make_plot(
    paths=[AC_path_actions, AC_path], 
    includes=[include_AC_act, include_AC], 
    excludes=[exclude_AC_act, exclude_AC],
    names=['AC Actions', 'AC Actor + Plan'],
    plot_name=' Reach ',
    save_path = save_path,
    plot_closest=False,
    find_closest=True,
    mean=False
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/Stats for MA/reach_actions_vs_actor/: 2
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-27: 2

# %%
from active_critic.analyze_stats.analyze_stats import make_plot

AC_path_actions = '/home/hendrik/Documents/master_project/LokalData/server/Stats for MA/reach_actions_vs_actor/'

include_AC_act = ['reach opt mode: actions demonstrations: 1, im_ph:False, training_episodes: 10, min critic: 5e-05, wd: 0.01, val_every: 2000 run', 'statsoptimized']
exclude_AC_act = []

AC_path = '/home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-27'
include_AC = ['reach sm manual_seed(2) no train inf eps: 2000 opt mode: actor+plan demonstrations: 1, im_ph:False, training_episodes: 10, min critic: 5e-05, wd: 0.01, val_every: 6000 ', 'statsoptimized']
exclude_AC = []

save_path = '/home/hendrik/Documents/master_project/LokalData/server/Stats for MA/Reach_1_2000_actions_app_long/'


make_plot(
    paths=[AC_path_actions, AC_path], 
    includes=[include_AC_act, include_AC], 
    excludes=[exclude_AC_act, exclude_AC],
    names=['AC Actions', 'AC Actor + Plan'],
    plot_name='Reach',
    save_path = None,
    plot_closest=False,
    find_closest=True,
    mean=False
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/Stats for MA/reach_actions_vs_actor/: 1
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-27: 2

# %%
from active_critic.analyze_stats.analyze_stats import make_plot


AC_path = '/home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-28/'
include_AC = ['reach sm manual_seed(1) no train inf eps: 2000 opt mode: actor+plan demonstrations: 1, im_ph:True, training_episodes: 10, min critic: 5e-05, wd: 0.01, val_every: 6000', 'statsoptimized']
exclude = []

make_plot(
    paths=[AC_path], 
    includes=[include_AC], 
    excludes=[exclude],
    names=['AC optimized', 'AC non optimized'],
    plot_name='Push Environment',
    save_path = None,
    plot_closest=False
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-28/: 2
