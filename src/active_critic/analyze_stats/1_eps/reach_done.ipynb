# %%
from active_critic.analyze_stats.analyze_stats import make_plot

# %%
from active_critic.analyze_stats.analyze_stats import make_plot
TQC_path = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-04-121_/'
include_TQC = ['learner', 'TQC_windowopen_lr_0.00073_demonstrations_0_n_samples_5000']
exclude_TQC = []

make_plot(
    paths=[TQC_path], 
    includes=[include_TQC], 
    excludes=[exclude_TQC],
    names=['AVC (ours)', 'PPO', 'TQC', 'RPPO'],
    plot_name='Reach',
    save_path = None,
    plot_closest=True,
    mean=False,
    total_plot_points=60,
    mark_every=None,
    font_size=14,
    legend_font_size = 14,
    find_closest=True
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-04-121_/: 3

# %%
AC_path = '/home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-04-12'
include_AC = ['statsoptimized', 'pickplace double critic ms 0 training eps: 15000 opt mode: actor+plan demonstrations: 4, im_ph:False, 10, run id: 0']
exlude_AC = []

make_plot(
    paths=[AC_path], 
    includes=[include_AC], 
    excludes=[exlude_AC],
    names=['AVC', 'PPO + BC', 'TQC + BC', 'RPPO + BC'],
    plot_name='Reach',
    save_path = None,
    plot_closest=True,
    mean=False,
    total_plot_points=100,
    mark_every=None,
    font_size=14,
    legend_font_size = 14,
    find_closest=True
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-04-12: 1

# %%
from active_critic.analyze_stats.analyze_stats import make_plot
PPO_path = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-26/'
include_PPO = ['PPO_reach_lr_1e-05_demonstrations_1_n_samples_2000', 'learner']
exclude_PPO = ['15']

TQC_path = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-26/'
include_TQC = ['TQC_reach_lr_1e-06_demonstrations_1_n_samples_2000', 'learner']
exclude_TQC = ['15']

RPPO_path = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-27/'
include_RPPO = ['RPPO_reach_lr_1e-05_demonstrations_1', 'learner']
exclude_RPPO = ['15']

AC_path = '/home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-27'
include_AC = ['reach sm manual_seed(2) no train inf eps: 2000 opt mode: actor+plan demonstrations: 1, im_ph:False, training_episodes: 10, min critic: 5e-05, wd: 0.01, val_every: 6000 ', 'statsoptimized']
exclude_AC = []


save_path = '/home/hendrik/Documents/Master Thesis/TUM_Thesis_Template_CSE/images/1_2000/'
make_plot(
    paths=[AC_path, PPO_path, TQC_path,  RPPO_path], 
    includes=[include_AC, include_PPO, include_TQC, include_RPPO], 
    excludes=[exclude_AC, exclude_PPO, exclude_TQC, exclude_RPPO],
    names=['AVC (ours)', 'PPO', 'TQC', 'RPPO'],
    plot_name='Reach',
    save_path = save_path,
    plot_closest=False,
    mean=False,
    total_plot_points=60,
    mark_every=None,
    font_size=28,
    legend_font_size = 18,
    plot_legend=True,
    loc='lower center'
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-27: 2
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-26/: 2
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-26/: 2
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-27/: 2

# %%
from active_critic.analyze_stats.analyze_stats import make_plot

AC_path_actions = '/home/hendrik/Documents/master_project/LokalData/server/Stats for MA/reach_actions_vs_actor/'

include_AC_act = ['reach opt mode: actions demonstrations: 1, im_ph:False, training_episodes: 10, min critic: 5e-05, wd: 0.01, val_every: 2000 run id: 0']
exclude_AC_act = []

AC_path = '/home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-27'
include_AC = ['reach sm manual_seed(2) no train inf eps: 2000 opt mode: actor+plan demonstrations: 1, im_ph:False, training_episodes: 10, min critic: 5e-05, wd: 0.01, val_every: 6000 ', 'statsoptimized']
exclude_AC = []

save_path = '/home/hendrik/Documents/Master Thesis/TUM_Thesis_Template_CSE/images/Plan_vs_Actions/'

make_plot(
    paths=[AC_path_actions, AC_path], 
    includes=[include_AC_act, include_AC], 
    excludes=[exclude_AC_act, exclude_AC],
    names=['AVC Actions', 'AVC Actor + Plan'],
    plot_name='Reach',
    save_path = save_path,
    plot_closest=False,
    find_closest=False,
    mean=False,
    total_plot_points=40,
    font_size=19,
    legend_font_size=18
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/Stats for MA/reach_actions_vs_actor/: 2
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-27: 2

# %%
from active_critic.analyze_stats.analyze_stats import plot_actions
AC_act_actions_path = '/data/bing/hendrik/AC_var_2023-04-11/'
include_AC = ['statsoptimized', 'reach double critic ms 0 training eps: 3000 opt mode: actor+plan demonstrations: 0, im_ph:False, 10, run id: 0']
exclude_AC = []

save_path = '/home/hendrik/Documents/Master Thesis/TUM_Thesis_Template_CSE/images/Plan_vs_Actions/vector_changes/'

plot_actions(
    paths=[AC_act_actions_path],
    includes=[include_AC],
    excludes=[exclude_AC],
    experiment_num=0,
    time_step=121,
    save_path=save_path,
    legend_fontsize=18,
    label_fontsize=19,
    title='Actor and Planner Optimizer Mode',
    ylabel='Act',
    tick_size=8
)
# Out:
# for path: /data/bing/hendrik/AC_var_2023-04-11/: 1

# %%
from active_critic.analyze_stats.analyze_stats import plot_actions
AC_act_actions_path = '/data/bing/hendrik/AC_var_2023-04-12/'
include_AC = ['statsoptimized', 'reach training 0 history eps: 400 opt mode: actions demonstrations: 1, im_ph:False, training_episodes: 10, min critic: 5e-05, wd: 0.01, val_every: 6000 run id: 0']
exclude_AC = []

save_path = '/home/hendrik/Documents/Master Thesis/TUM_Thesis_Template_CSE/images/Plan_vs_Actions/vector_changes/'

plot_actions(
    paths=[AC_act_actions_path],
    includes=[include_AC],
    excludes=[exclude_AC],
    experiment_num=0,
    time_step=9,
    save_path=save_path,
    legend_fontsize=18,
    label_fontsize=19,
    title='Actions Optimizer Mode',
    ylabel='Act',
    tick_size=8
)
# Out:
# for path: /data/bing/hendrik/AC_var_2023-04-12/: 1

# %%
from active_critic.analyze_stats.analyze_stats import make_plot
AC_path = '/home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-27'
include_AC = ['reach sm manual_seed(2) no train inf eps: 2000 opt mode: actor+plan demonstrations: 1, im_ph:False, training_episodes: 10, min critic: 5e-05, wd: 0.01, val_every: 6000 ', 'statsoptimized']
exclude_AC = []

AC_path_im = '/home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-28/'
include_AC_im = ['reach sm manual_seed(1) no train inf eps: 2000 opt mode: actor+plan demonstrations: 1, im_ph:True, training_episodes: 10, min critic: 5e-05, wd: 0.01, val_every: 6000', 'statsoptimized']
exclude_im = []

save_path = '/home/hendrik/Documents/Master Thesis/TUM_Thesis_Template_CSE/images/1_2000_imi/'
make_plot(
    paths=[AC_path, AC_path_im], 
    includes=[include_AC, include_AC_im], 
    excludes=[exclude_AC, exclude_im],
    names=['AC with Reinforcement', 'AC Imitation Only'],
    plot_name='Reach',
    save_path = save_path,
    plot_closest=False,
    find_closest=False,
    total_plot_points=60,
    font_size=19,
    legend_font_size=14,
    plot_legend=True
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-27: 2
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-28/: 2
