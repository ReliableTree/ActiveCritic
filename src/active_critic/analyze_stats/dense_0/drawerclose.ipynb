# %%
from active_critic.analyze_stats.analyze_stats import make_plot

AC_path = '/data/bing/hendrik/AC_var_2023-03-31/'
include_AC = ['statsoptimized']
exclude_AC = []

make_plot(
    paths=[AC_path], 
    includes=[include_AC], 
    excludes=[exclude_AC],
    names=['AC with Reinforcement', 'AC Imitation Only'],
    plot_name='Window Open',
    save_path = None,
    plot_closest=False,
    mean=False
    )
# Out:
# for path: /data/bing/hendrik/AC_var_2023-03-31/: 1
