# %%
from active_critic.analyze_stats.analyze_stats import make_plot

AC_path = '/home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-31/'
include_AC = ['statsoptimized', 'drawerclose ms 0 explore_until 3 reset drawerclose opt steps: 1 trainin eps: 500 opt mode: actor+plan demonstrations: 0, im_ph:False, training_episodes: 10, min critic: 1e-05, wd: 0.01, val_every: 1000']
exclude_AC = []


PPO_path = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-31/'
include_PPO = ['learner', 'PPO_drawerclose_lr_0.0005_demonstrations_0_n_samples_1000']
exclude_PPO = []

TQC_path = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-04-012_/'
include_TQC = ['learner', 'TQC_drawerclose_dense_True_lr_5e-05_demonstrations_0_n_samples_1000_seqlen_100_learning_starts_3000']
exclude_TQC = []

save_path = '/home/hendrik/Documents/Master Thesis/TUM_Thesis_Template_CSE/images/dense_0/'


make_plot(
    paths=[AC_path, PPO_path, TQC_path], 
    includes=[include_AC, include_PPO, include_TQC], 
    excludes=[exclude_AC, exclude_PPO, exclude_TQC],
    names=['AVC', 'PPO', 'TQC', 'RPPO'],
    plot_name='Drawer Close',
    save_path = save_path,
    plot_closest=False,
    mean=False,
    total_plot_points=60
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-31/: 3
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-31/: 3
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-04-012_/: 3

# %%
from active_critic.analyze_stats.analyze_stats import make_plot

AC_path = '/home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-31/'
include_AC = ['statsoptimized', 'drawerclose ms 0 explore_until 3 reset drawerclose opt steps: 1 trainin eps: 500 opt mode: actor+plan demonstrations: 0, im_ph:False, training_episodes: 10, min critic: 1e-05, wd: 0.01, val_every: 1000']
exclude_AC = []

AC_path_sp = '/home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-28/'
include_AC_sp = ['drawerclose sm manual_seed(0) no train inf eps: 1000 opt mode: actor+plan demonstrations: 0, im_ph:False, training_episodes: 10, min critic: 5e-05, wd: 0.01, val_every: 6000', 'stats']
exclude_AC_sp = ['optimized']

save_path = '/home/hendrik/Documents/Master Thesis/TUM_Thesis_Template_CSE/images/dense_vs_sparse_0/'


make_plot(
    paths=[AC_path, AC_path_sp], 
    includes=[include_AC, include_AC_sp], 
    excludes=[exclude_AC, exclude_AC_sp],
    names=['AVC Dense Observations', 'AVC Single Observations'],
    plot_name='Window Open',
    save_path = save_path,
    plot_closest=True,
    mean=False,
    total_plot_points=60
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-31/: 3
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-03-28/: 4

# %%
AC_path = '/home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-04-01/'
include_AC = ['statsoptimized', 'drawerclose rand act ms 1 trainin eps: 1000 opt mode: actor+plan demonstrations: 0, im_ph:False, 10']
exclude_AC = [' id: 2']
make_plot(
    paths=[AC_path], 
    includes=[include_AC], 
    excludes=[exclude_AC],
    names=['AC', 'PPO + BC', 'TQC + BC'],
    plot_name='Push Environment',
    save_path = None,
    plot_closest=False
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/AC/AC_var_2023-04-01/: 2
