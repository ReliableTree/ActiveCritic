# %%
from active_critic.analyze_stats.analyze_stats import make_plot

# %%
TQC_path_0 = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-31/'
include_TQC_0 = ['learner', 'TQC_windowopen_lr_0.00073_demonstrations_0_n_samples_5000']
exclude_TQC_0 = ['id_2', 'id_1']

TQC_path_bc = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-30/'
include_TQC_bc = ['learner', "TQC_windowopen_lr_0.0001_demonstrations_1_n_samples_5000"]
exclude_TQC_bc = []

save_path = '/home/hendrik/Documents/Master Thesis/TUM_Thesis_Template_CSE/images/TQC_bc_vs_ref/'


make_plot(
    paths=[TQC_path_0, TQC_path_bc], 
    includes=[include_TQC_0, include_TQC_bc], 
    excludes=[exclude_TQC_0, exclude_TQC_bc],
    names=['TQC', 'TQC + BC'],
    plot_name='Window Open',
    save_path = None,
    plot_closest=False,
    mean=False,
    find_closest=True
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-31/: 1
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-30/: 1
