# %%
from active_critic.analyze_stats.analyze_stats import make_plot

# %%
TQC_path = '/home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-31/'
include_TQC = ['learner', 'TQC_windowopen_lr_0.00073_demonstrations_0_n_samples_5000']
exclude_TQC = ['id_2', 'id_0']

make_plot(
    paths=[TQC_path], 
    includes=[include_TQC], 
    excludes=[exclude_TQC],
    names=['AC', 'PPO', 'TQC', 'RPPO'],
    plot_name='Drawer Close',
    save_path = None,
    plot_closest=False,
    mean=False,
    find_closest=True
    )
# Out:
# for path: /home/hendrik/Documents/master_project/LokalData/server/baselines/Baselines_Stats_GAIL_2023-03-31/: 1
